# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv


# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 2.7.16 |Anaconda, Inc.| (default, Sep 24 2019, 21:51:30)
# [GCC 7.3.0]
# Pandas version 0.24.2
# Matplotlib version 2.2.3

# %%
train = pd.read_csv("data/febrouary/listings.csv")
idF=train.id
nameF=train.name
descriptionF=train.description
transitF=train.transit
instant_bookableF=train.instant_bookable
host_sinceF =train.host_since
host_response_rateF=train.host_response_rate
host_identity_verifiedF=train.host_identity_verified
host_has_profile_picF=train.host_has_profile_pic
first_reviewF=train.first_review
bed_typeF=train.bed_type
bathroomsF=train.bathrooms
bedsF=train.beds
accommodatesF=train.accommodates
amenitiesF=train.amenities
room_typeF=train.room_type
property_typeF=train.property_type
cancellation_policyF=train.cancellation_policy
zipcodeF=train.zipcode
cityF=train.city
availability_365F=train.availability_365
review_scores_ratingF=train.review_scores_rating
number_of_reviewsF=train.number_of_reviews
neighbourhoodF=train.neighbourhood
latitudeF=train.latitude
longitudeF=train.longitude
room_typeF=train.room_type
number_of_reviewsF=train.number_of_reviews
availability_365F=train.availability_365
neighbourhoodF=train.neighbourhood
priceF =train.price
minimum_nightsF=train.minimum_nights
last_reviewF=train.last_review
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-38b5ee42842d> in <module>()
# ----> 1 train = pd.read_csv("data/febrouary/listings.csv")
#       2 idF=train.id
#       3 nameF=train.name
#       4 descriptionF=train.description
#       5 transitF=train.transit
#
# ...

# %%
train = pd.read_csv("data/march/listings.csv")
idM=train.id
nameM=train.name
descriptionM=train.description
transitM=train.transit
instant_bookableM=train.instant_bookable
host_sinceM =train.host_since
host_response_rateM=train.host_response_rate
host_identity_verifiedM=train.host_identity_verified
host_has_profile_picM=train.host_has_profile_pic
first_reviewM=train.first_review
bed_typeM=train.bed_type
bathroomsM=train.bathrooms
bedsM=train.beds
accommodatesM=train.accommodates
amenitiesM=train.amenities
room_typeM=train.room_type
property_typeM=train.property_type
cancellation_policyM=train.cancellation_policy
zipcodeM=train.zipcode
cityM=train.city
availability_365M=train.availability_365
review_scores_ratingM=train.review_scores_rating
number_of_reviewsM=train.number_of_reviews
neighbourhoodM=train.neighbourhood
latitudeM=train.latitude
longitudeM=train.longitude
room_typeM=train.room_type
number_of_reviewsM=train.number_of_reviews
availability_365M=train.availability_365
neighbourhoodM=train.neighbourhood
priceM =train.price
minimum_nightsM=train.minimum_nights
last_reviewM=train.last_review

# %%
train = pd.read_csv("data/april/listings.csv")
idA=train.id
nameA=train.name
descriptionA=train.description
transitA=train.transit
instant_bookableA=train.instant_bookable
host_sinceA =train.host_since
host_response_rateA=train.host_response_rate
host_identity_verifiedA=train.host_identity_verified
host_has_profile_picA=train.host_has_profile_pic
first_reviewA=train.first_review
bed_typeA=train.bed_type
bathroomsA=train.bathrooms
bedsA=train.beds
accommodatesA=train.accommodates
amenitiesA=train.amenities
room_typeA=train.room_type
property_typeA=train.property_type
cancellation_policyA=train.cancellation_policy
zipcodeA=train.zipcode
cityA=train.city
availability_365A=train.availability_365
review_scores_ratingA=train.review_scores_rating
number_of_reviewsA=train.number_of_reviews
neighbourhoodA=train.neighbourhood
latitudeA=train.latitude
longitudeA=train.longitude
room_typeA=train.room_type
number_of_reviewsA=train.number_of_reviews
availability_365A=train.availability_365
neighbourhoodA=train.neighbourhood
priceA =train.price
minimum_nightsA=train.minimum_nights
last_reviewA=train.last_review

ASet_listings=list(zip(idA,nameA,descriptionA))

# %%
Set_list=list(zip(
idF,
nameF,
descriptionF,
transitF,
instant_bookableF,
host_sinceF,
host_response_rateF,
host_identity_verifiedF,
host_has_profile_picF,
first_reviewF,
bed_typeF,
bathroomsF,
bedsF,
accommodatesF,
amenitiesF,
room_typeF,
property_typeF,
cancellation_policyF,
zipcodeF,
cityF,
availability_365F,
review_scores_ratingF,
number_of_reviewsF,
neighbourhoodF,
latitudeF,
longitudeF,
room_typeF,
number_of_reviewsF,
availability_365F,
neighbourhoodF,
priceF ,
minimum_nightsF,last_reviewF,
    
idM,
nameM,
descriptionM,
transitM,
instant_bookableM,
host_sinceM,
host_response_rateM,
host_identity_verifiedM,
host_has_profile_picM,
first_reviewM,
bed_typeM,
bathroomsM,
bedsM,
accommodatesM,
amenitiesM,
room_typeM,
property_typeM,
cancellation_policyM,
zipcodeM,
cityM,
availability_365M,
review_scores_ratingM,
number_of_reviewsM,
neighbourhoodM,
latitudeM,
longitudeM,
room_typeM,
number_of_reviewsM,
availability_365M,
neighbourhoodM,
priceM ,
minimum_nightsM,last_reviewM,

idA,
nameA,
descriptionA,
transitA,
instant_bookableA,
host_sinceA,
host_response_rateA,
host_identity_verifiedA,
host_has_profile_picA,
first_reviewA,
bed_typeA,
bathroomsA,
bedsA,
accommodatesA,
amenitiesA,
room_typeA,
property_typeA,
cancellation_policyA,
zipcodeA,
cityA,
availability_365A,
review_scores_ratingA,
number_of_reviewsA,
neighbourhoodA,
latitudeA,
longitudeA,
room_typeA,
number_of_reviewsA,
availability_365A,
neighbourhoodA,
priceA ,
minimum_nightsA,last_reviewA))

# %%
train = pd.DataFrame(data = Set_list , 
                  columns=[
'idF',
'nameF',
'descriptionF',
'transitF',
'instant_bookableF',
'host_sinceF',
'host_response_rateF',
'host_identity_verifiedF',
'host_has_profile_picF',
'first_reviewF',
'bed_typeF',
'bathroomsF',
'bedsF',
'accommodatesF',
'amenitiesF',
'room_typeF',
'property_typeF',
'cancellation_policyF',
'zipcodeF',
'cityF',
'availability_365F',
'review_scores_ratingF',
'number_of_reviewsF',
'neighbourhoodF',
'latitudeF',
'longitudeF',
'room_typeF',
'number_of_reviewsF',
'availability_365F',
'neighbourhoodF',
'priceF' ,
'minimum_nightsF','last_reviewF',
    
'idM',
'nameM',
'descriptionM',
'transitM',
'instant_bookableM',
'host_sinceM',
'host_response_rateM',
'host_identity_verifiedM',
'host_has_profile_picM',
'first_reviewM',
'bed_typeM',
'bathroomsM',
'bedsM',
'accommodatesM',
'amenitiesM',
'room_typeM',
'property_typeM',
'cancellation_policyM',
'zipcodeM',
'cityM',
'availability_365M',
'review_scores_ratingM',
'number_of_reviewsM',
'neighbourhoodM',
'latitudeM',
'longitudeM',
'room_typeM',
'number_of_reviewsM',
'availability_365M',
'neighbourhoodM',
'priceM' ,
'minimum_nightsM','last_reviewM',

'idA',
'nameA',
'descriptionA',
'transitA',
'instant_bookableA',
'host_sinceA',
'host_response_rateA',
'host_identity_verifiedA',
'host_has_profile_picA',
'first_reviewA',
'bed_typeA',
'bathroomsA',
'bedsA',
'accommodatesA',
'amenitiesA',
'room_typeA',
'property_typeA',
'cancellation_policyA',
'zipcodeA',
'cityA',
'availability_365A',
'review_scores_ratingA',
'number_of_reviewsA',
'neighbourhoodA',
'latitudeA',
'longitudeA',
'room_typeA',
'number_of_reviewsA',
'availability_365A',
'neighbourhoodA',
'priceA' ,
'minimum_nightsA','last_reviewA'
                                         
                          ])

# %%
train.to_csv('train.csv',
             index=
['idF',
'nameF',
'descriptionF',
'transitF',
'instant_bookableF',
'host_sinceF',
'host_response_rateF',
'host_identity_verifiedF',
'host_has_profile_picF',
'first_reviewF',
'bed_typeF',
'bathroomsF',
'bedsF',
'accommodatesF',
'amenitiesF',
'room_typeF',
'property_typeF',
'cancellation_policyF',
'zipcodeF',
'cityF',
'availability_365F',
'review_scores_ratingF',
'number_of_reviewsF',
'neighbourhoodF',
'latitudeF',
'longitudeF',
'room_typeF',
'number_of_reviewsF',
'availability_365F',
'neighbourhoodF',
'priceF' ,
'minimum_nightsF', 'last_reviewF',
'idM',
'nameM',
'descriptionM',
'transitM',
'instant_bookableM',
'host_sinceM',
'host_response_rateM',
'host_identity_verifiedM',
'host_has_profile_picM',
'first_reviewM',
'bed_typeM',
'bathroomsM',
'bedsM',
'accommodatesM',
'amenitiesM',
'room_typeM',
'property_typeM',
'cancellation_policyM',
'zipcodeM',
'cityM',
'availability_365M',
'review_scores_ratingM',
'number_of_reviewsM',
'neighbourhoodM',
'latitudeM',
'longitudeM',
'room_typeM',
'number_of_reviewsM',
'availability_365M',
'neighbourhoodM',
'priceM' ,
'minimum_nightsM','last_reviewM',
'idA',
'nameA',
'descriptionA',
'transitA',
'instant_bookableA',
'host_sinceA',
'host_response_rateA',
'host_identity_verifiedA',
'host_has_profile_picA',
'first_reviewA',
'bed_typeA',
'bathroomsA',
'bedsA',
'accommodatesA',
'amenitiesA',
'room_typeA',
'property_typeA',
'cancellation_policyA',
'zipcodeA',
'cityA',
'availability_365A',
'review_scores_ratingA',
'number_of_reviewsA',
'neighbourhoodA',
'latitudeA',
'longitudeA',
'room_typeA',
'number_of_reviewsA',
'availability_365A',
'neighbourhoodA',
'priceA' ,
'minimum_nightsA','last_reviewA'],
             
 header=['idF',
'nameF',
'descriptionF',
'transitF',
'instant_bookableF',
'host_sinceF',
'host_response_rateF',
'host_identity_verifiedF',
'host_has_profile_picF',
'first_reviewF',
'bed_typeF',
'bathroomsF',
'bedsF',
'accommodatesF',
'amenitiesF',
'room_typeF',
'property_typeF',
'cancellation_policyF',
'zipcodeF',
'cityF',
'availability_365F',
'review_scores_ratingF',
'number_of_reviewsF',
'neighbourhoodF',
'latitudeF',
'longitudeF',
'room_typeF',
'number_of_reviewsF',
'availability_365F',
'neighbourhoodF',
'priceF' ,
'minimum_nightsF', 'last_reviewF',  
'idM',
'nameM',
'descriptionM',
'transitM',
'instant_bookableM',
'host_sinceM',
'host_response_rateM',
'host_identity_verifiedM',
'host_has_profile_picM',
'first_reviewM',
'bed_typeM',
'bathroomsM',
'bedsM',
'accommodatesM',
'amenitiesM',
'room_typeM',
'property_typeM',
'cancellation_policyM',
'zipcodeM',
'cityM',
'availability_365M',
'review_scores_ratingM',
'number_of_reviewsM',
'neighbourhoodM',
'latitudeM',
'longitudeM',
'room_typeM',
'number_of_reviewsM',
'availability_365M',
'neighbourhoodM',
'priceM' ,
'minimum_nightsM','last_reviewM',
'idA',
'nameA',
'descriptionA',
'transitA',
'instant_bookableA',
'host_sinceA',
'host_response_rateA',
'host_identity_verifiedA',
'host_has_profile_picA',
'first_reviewA',
'bed_typeA',
'bathroomsA',
'bedsA',
'accommodatesA',
'amenitiesA',
'room_typeA',
'property_typeA',
'cancellation_policyA',
'zipcodeA',
'cityA',
'availability_365A',
'review_scores_ratingA',
'number_of_reviewsA',
'neighbourhoodA',
'latitudeA',
'longitudeA',
'room_typeA',
'number_of_reviewsA',
'availability_365A',
'neighbourhoodA',
'priceA' ,
'minimum_nightsA','last_reviewA',])
